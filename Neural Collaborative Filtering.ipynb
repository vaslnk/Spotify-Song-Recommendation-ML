# %%
import pandas as pd
import numpy as np
import scipy.sparse as sp
import json
# Out:
# Using Theano backend.

# %% [markdown]
# # CF Using Neural Collaborative Filtering
# In the world of reccomender sytems, collabrative filtering is usually done through matrix factorization using the inner product on the latent features of users and items. According to Xiangnan He from the National University of Sigapore, forcing the features to be orthgonal using the inner product limits the features that can be extracted. He believes this can have significant performance implicaitons especially when dealing with implifict feedback (1 if consumed, 0 if not consumed) where natural negative feedback is not easily availible.
#
# In his paper entitled, [Nerual Collaborative Filtering](https://arxiv.org/pdf/1708.05031.pdf) He argues that using a nueral network to do the dimentionality reduction is a form of general matrix factorization (GMF) that can improve performance. Here we explore that possibility using Spotify's 1M Challenge Data.
#
# Below is his proposed network for GMF that we will implement on a subset of our 1M Challenge Data.
#
# ![GMF.png](GMF.png)
#
# ## Preparing Dataset
# Let's begin by reading in our dataset.

# %%
#Create a function to read in json 
def readin_json(start):
    if start not in np.arange(0, 1000000, 1000):
        raise Exception('Invalid start pid! Start pids must be {0, 1000, 2000, ..., 999000}')
    end=start+1000
    path = 'data/mpd.slice.' + str(start) + "-" + str(end-1) + '.json'
    d = json.load(open(path, 'r'))
    thisslice = pd.DataFrame.from_dict(d['playlists'], orient='columns')
    return thisslice

# %%
#Read in a subset of our 1M Playlists
first1000 = readin_json(0)
second1000 = readin_json(1000)
third1000 = readin_json(2000)
traindata = pd.concat([first1000, second1000, third1000])

# %%
#Also read in the challenge dataset which has missing songs we 
#want our model to predict
t = json.load(open('data/challenge_set.json'))
challenge_df = pd.DataFrame.from_dict(t['playlists'], orient='columns')
#Combine train and challenge so we can use cat code to map
#track ids to an index 0-N across both datasets
train_challengedata = pd.concat([traindata, challenge_df])

# %%
#Turn playlist level dataframe into song level dataframe
songPlaylistArray = []
for index, row in train_challengedata.iterrows():
    for track in row['tracks']:
        songPlaylistArray.append([track['track_uri'], track['artist_name'], track['track_name'], row['pid'], row['num_holdouts']])
songPlaylist = pd.DataFrame(songPlaylistArray, columns=['trackid', 'artist_name', 'track_name', 'pid', 'num_holdouts'])

print(songPlaylist.shape)
songPlaylist.head(10)   #is a df of all track ids, cooresponding artist names, track names and playlist ids
# Out:
# (480874, 5)
#                                 trackid         artist_name  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI       Missy Elliott
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak      Britney Spears
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv             Beyoncé
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT   Justin Timberlake
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H              Shaggy
# 5  spotify:track:0XUfyU2QviPAs6bxSpXYG4               Usher
# 6  spotify:track:68vgtRHr7iZHpzGpon6Jlo               Usher
# 7  spotify:track:3BxWKCI06eQ5Od8TY2JBeA  The Pussycat Dolls
# 8  spotify:track:7H6ev70Weq6DdpZyyTmUXk     Destiny's Child
# 9  spotify:track:2PpruBYCo4H7WOBJ7Q2EwM             OutKast
#
#                                    track_name  pid  num_holdouts
# 0  Lose Control (feat. Ciara & Fat Man Scoop)    0           NaN
# 1                                       Toxic    0           NaN
# 2                               Crazy In Love    0           NaN
# 3                              Rock Your Body    0           NaN
# 4                                It Wasn't Me    0           NaN
# 5                                       Yeah!    0           NaN
# 6                                      My Boo    0           NaN
# 7                                     Buttons    0           NaN
# 8                                 Say My Name    0           NaN
# 9              Hey Ya! - Radio Mix / Club Mix    0           NaN

# %%
# Turn songs into their unqiue cat codes so we have a 0-N index for tracks
songPlaylist['trackindex'] = songPlaylist['trackid'].astype('category').cat.codes
print(len(songPlaylist['trackindex'].unique()))
songPlaylist.head(10)
# Out:
# 110716
#                                 trackid         artist_name  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI       Missy Elliott
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak      Britney Spears
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv             Beyoncé
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT   Justin Timberlake
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H              Shaggy
# 5  spotify:track:0XUfyU2QviPAs6bxSpXYG4               Usher
# 6  spotify:track:68vgtRHr7iZHpzGpon6Jlo               Usher
# 7  spotify:track:3BxWKCI06eQ5Od8TY2JBeA  The Pussycat Dolls
# 8  spotify:track:7H6ev70Weq6DdpZyyTmUXk     Destiny's Child
# 9  spotify:track:2PpruBYCo4H7WOBJ7Q2EwM             OutKast
#
#                                    track_name  pid  num_holdouts  trackindex
# 0  Lose Control (feat. Ciara & Fat Man Scoop)    0           NaN        7076
# 1                                       Toxic    0           NaN       89461
# 2                               Crazy In Love    0           NaN        7619
# 3                              Rock Your Body    0           NaN       16714
# 4                                It Wasn't Me    0           NaN       25336
# 5                                       Yeah!    0           NaN        7769
# 6                                      My Boo    0           NaN       87321
# 7                                     Buttons    0           NaN       45441
# 8                                 Say My Name    0           NaN      103422
# 9              Hey Ya! - Radio Mix / Club Mix    0           NaN       34437

# %%
# split appart training and challenge data
train = songPlaylist[pd.isnull(songPlaylist['num_holdouts'])]
challenge = songPlaylist[pd.notnull(songPlaylist['num_holdouts'])]

# %%
train.head(10)
# Out:
#                                 trackid         artist_name  \
# 0  spotify:track:0UaMYEvWZi0ZqiDOoHU3YI       Missy Elliott
# 1  spotify:track:6I9VzXrHxO9rA9A5euc8Ak      Britney Spears
# 2  spotify:track:0WqIKmW4BTrj3eJFmnCKMv             Beyoncé
# 3  spotify:track:1AWQoqb9bSvzTjaLralEkT   Justin Timberlake
# 4  spotify:track:1lzr43nnXAijIGYnCT8M8H              Shaggy
# 5  spotify:track:0XUfyU2QviPAs6bxSpXYG4               Usher
# 6  spotify:track:68vgtRHr7iZHpzGpon6Jlo               Usher
# 7  spotify:track:3BxWKCI06eQ5Od8TY2JBeA  The Pussycat Dolls
# 8  spotify:track:7H6ev70Weq6DdpZyyTmUXk     Destiny's Child
# 9  spotify:track:2PpruBYCo4H7WOBJ7Q2EwM             OutKast
#
#                                    track_name  pid  num_holdouts  trackindex
# 0  Lose Control (feat. Ciara & Fat Man Scoop)    0           NaN        7076
# 1                                       Toxic    0           NaN       89461
# 2                               Crazy In Love    0           NaN        7619
# 3                              Rock Your Body    0           NaN       16714
# 4                                It Wasn't Me    0           NaN       25336
# 5                                       Yeah!    0           NaN        7769
# 6                                      My Boo    0           NaN       87321
# 7                                     Buttons    0           NaN       45441
# 8                                 Say My Name    0           NaN      103422
# 9              Hey Ya! - Radio Mix / Club Mix    0           NaN       34437

# %%
#Save data in dok matrix (optimized sparse matrix object)
    #Create a sparse pid x trackindex matrix
    #If a pid i has song j, mat[i,j]=1
mat = sp.dok_matrix((3000, 110716), dtype=np.float32)
for pid, trackindex in zip(train['pid'], train['trackindex']):
    mat[pid, trackindex] = 1.0

# %% [markdown]
# ## Building and NN Using Keras

# %%
import numpy as np
import theano.tensor as T
import keras
from keras import backend as K
from keras import initializations
from keras.models import Sequential, Model, load_model, save_model
from keras.layers.core import Dense, Lambda, Activation
from keras.layers import Embedding, Input, Dense, merge, Reshape, Merge, Flatten
from keras.optimizers import Adam
from keras.regularizers import l2
from time import time
import multiprocessing as mp
import sys
import math

def init_normal(shape, name=None):
    return initializations.normal(shape, scale=0.01, name=name)

def get_model(num_users, num_items, latent_dim, regs=[0,0]):
    # Input variables
    user_input = Input(shape=(1,), dtype='int32', name = 'user_input')
    item_input = Input(shape=(1,), dtype='int32', name = 'item_input')

    MF_Embedding_User = Embedding(input_dim = num_users, output_dim = latent_dim, name = 'user_embedding',
                                  init = init_normal, W_regularizer = l2(regs[0]), input_length=1)
    MF_Embedding_Item = Embedding(input_dim = num_items, output_dim = latent_dim, name = 'item_embedding',
                                  init = init_normal, W_regularizer = l2(regs[1]), input_length=1)   
    
    # Crucial to flatten an embedding vector!
    user_latent = Flatten()(MF_Embedding_User(user_input))
    item_latent = Flatten()(MF_Embedding_Item(item_input))
    
    # Element-wise product of user and item embeddings 
    predict_vector = merge([user_latent, item_latent], mode = 'mul')
    
    # Final prediction layer
    #prediction = Lambda(lambda x: K.sigmoid(K.sum(x)), output_shape=(1,))(predict_vector)
    prediction = Dense(1, activation='sigmoid', init='lecun_uniform', name = 'prediction')(predict_vector)
    
    model = Model(input=[user_input, item_input], 
                output=prediction)
    return model

def get_train_instances(train, num_negatives):
    user_input, item_input, labels = [],[],[]
    num_users = train.shape[0]
    for (u, i) in train.keys():
        # positive instance
        user_input.append(u)
        item_input.append(i)
        labels.append(1)
        # negative instances
        for t in xrange(num_negatives):
            j = np.random.randint(num_items)
            while train.has_key((u, j)):
                j = np.random.randint(num_items)
            user_input.append(u)
            item_input.append(j)
            labels.append(0)
    return user_input, item_input, labels

# Specify hyperparameters
num_factors = 8
regs = [0,0]
num_negatives = 4
learner = 'adam'
learning_rate = 0.001
epochs = 15
batch_size = 200
verbose = 1

# Save model
model_out_file = './GMF_%d_%d.h5' %(num_factors, time())
    
# Loading data
train = mat
num_users, num_items = train.shape
print("Load data done")

# Build model
model = get_model(num_users, num_items, num_factors, regs)
model.compile(optimizer=Adam(lr=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
print(model.summary())
    
# Train model
for epoch in xrange(epochs):
    # Generate training instances
    user_input, item_input, labels = get_train_instances(train, num_negatives)

    # Training
    hist = model.fit([np.array(user_input), np.array(item_input)], #input
                     np.array(labels), # labels 
                     validation_split=0.20, batch_size=batch_size, nb_epoch=1, verbose=0, shuffle=True)
    print(hist.history)
# Out:
# Load data done
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# item_input (InputLayer)          (None, 1)             0
# ____________________________________________________________________________________________________
# user_input (InputLayer)          (None, 1)             0
# ____________________________________________________________________________________________________
# item_embedding (Embedding)       (None, 1, 8)          885728      item_input[0][0]
# ____________________________________________________________________________________________________
# user_embedding (Embedding)       (None, 1, 8)          24000       user_input[0][0]
# ____________________________________________________________________________________________________
# flatten_13 (Flatten)             (None, 8)             0           user_embedding[0][0]
# ____________________________________________________________________________________________________
# flatten_14 (Flatten)             (None, 8)             0           item_embedding[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, 8)             0           flatten_13[0][0]
#                                                                    flatten_14[0][0]
# ____________________________________________________________________________________________________
# prediction (Dense)               (None, 1)             9           merge_7[0][0]
# ====================================================================================================
# Total params: 909737
# ____________________________________________________________________________________________________
# None
# {'acc': [0.80554373147785574], 'loss': [0.5074939449317093], 'val_acc': [0.83409850456268331], 'val_loss': [0.41650325220576218]}
# {'acc': [0.85678904575393999], 'loss': [0.36208227252638836], 'val_acc': [0.86201480192001001], 'val_loss': [0.36864483411447174]}
# {'acc': [0.87554981164370693], 'loss': [0.29690788409908553], 'val_acc': [0.86834904502877541], 'val_loss': [0.36912439977239547]}
# {'acc': [0.89305639793424119], 'loss': [0.24866576075366628], 'val_acc': [0.8684655952153989], 'val_loss': [0.39078940778405902]}
# {'acc': [0.91122174950746393], 'loss': [0.21091897480867125], 'val_acc': [0.86688963427808952], 'val_loss': [0.42330731592413212]}
# {'acc': [0.92548267106716542], 'loss': [0.18222762357503602], 'val_acc': [0.86615486190688029], 'val_loss': [0.4612088430745751]}
# {'acc': [0.93593670753549751], 'loss': [0.15994422342331863], 'val_acc': [0.86603831218539906], 'val_loss': [0.50236623643548151]}
# {'acc': [0.94309060158211977], 'loss': [0.14417692399787163], 'val_acc': [0.86755346260595623], 'val_loss': [0.54586900501093194]}
# {'acc': [0.94881549137781807], 'loss': [0.13214823270120876], 'val_acc': [0.86779163046135444], 'val_loss': [0.58530840514773497]}
# {'acc': [0.95327606733789849], 'loss': [0.12284873489540037], 'val_acc': [0.86819702260603204], 'val_loss': [0.62672637475954074]}
# {'acc': [0.95763276236040606], 'loss': [0.11398804795309966], 'val_acc': [0.86827810082837198], 'val_loss': [0.6672732047098584]}
# {'acc': [0.96027034293666513], 'loss': [0.10822112559218851], 'val_acc': [0.86907874840159083], 'val_loss': [0.70617166124990283]}
# {'acc': [0.96317776332658345], 'loss': [0.10242271355796068], 'val_acc': [0.86949427605424356], 'val_loss': [0.74532679612844133]}
# {'acc': [0.96612699096526877], 'loss': [0.096856961674381167], 'val_acc': [0.87073578692695541], 'val_loss': [0.78225508536129751]}
# {'acc': [0.96745718301725903], 'loss': [0.094472296182864721], 'val_acc': [0.86955508373181634], 'val_loss': [0.81817948569325527]}

# %% [markdown]
# ## Generating Reccomendations for Challenge Playlists
#
# Having trained our model, we will use our model to predict the missing songs in the challenge playlist. While we don't have access to Spotify's evaluation script, we can do a sanity check by just exmaining the reccomendaitons to see if they make any sense.

# %%
#Challenge pid's are indexed wierd since empty playlists were removed by out groupby
#Let's manually reindex
challenge.loc[challenge['pid']== 1000000, 'pid'] = 0
challenge.loc[challenge['pid']== 1000016, 'pid'] = 1
challenge.loc[challenge['pid']== 1000020, 'pid'] = 2
challenge.loc[challenge['pid']== 1000023,'pid'] = 3

# %%
sample_challenge = challenge[1:20]
sample_challenge
# Out:
#                                      trackid              artist_name  \
# 199875  spotify:track:5MhsZlmKJG6X5kTHkdwC4B                AronChupa
# 199876  spotify:track:0GZoB8h0kqXn7XFm4Sj06k                    Lorde
# 199877  spotify:track:35kahykNu00FPysz3C2euR                    Lorde
# 199878  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1                    Lorde
# 199879  spotify:track:6WQLkih8nE0JdUCEyLaGnQ                   Alesso
# 199880  spotify:track:37sINbJZcFdHFAsVNsPq1i               The Script
# 199881  spotify:track:0yhPEz5KxlDwckGJaMlZqM             Fall Out Boy
# 199882  spotify:track:5j9iuo3tMmQIfnEEQOOjxh         American Authors
# 199883  spotify:track:4eLSCSELtKxZwXnFbNLXT5          Imagine Dragons
# 199884  spotify:track:4PvD06Pmbm2rHG2JjSlElF                    Banks
# 199885  spotify:track:57nNNkgk768QVXq3uHxu5e                Grouplove
# 199886  spotify:track:3y8AEUef1AVfr0npU5UOa9                 Big Data
# 199887  spotify:track:5jJ69cMDMC0aeWPjZo6VP2             Modest Mouse
# 199888  spotify:track:02b5L9jExmkRTdUTqXFzmR  Marina and the Diamonds
# 199889  spotify:track:6fKEplI9iN0JMHsRGQESaT                 Galantis
# 199890  spotify:track:3ebXMykcMXOcLeJ9xZ17XH            Martin Garrix
# 199891  spotify:track:1J9KJgXKFRqKGIzmJ7GjS3              Just A Gent
# 199892  spotify:track:6aBYg6Npa47VAqtEsLsUdz                  Carmada
# 199893  spotify:track:0dA2Mk56wEzDgegdC6R17g                     Zedd
#
#                                                track_name  pid  num_holdouts  \
# 199875                                   I'm an Albatraoz    0          70.0
# 199876  Yellow Flicker Beat - From The Hunger Games: M...    0          70.0
# 199877                                  White Teeth Teens    0          70.0
# 199878                                               Team    0          70.0
# 199879                               Heroes (we could be)    1          73.0
# 199880                                        Superheroes    1          73.0
# 199881                                          Centuries    1          73.0
# 199882                                Best Day Of My Life    1          73.0
# 199883                                On Top Of The World    1          73.0
# 199884                                  Beggin For Thread    2          63.0
# 199885                                         Ways To Go    2          63.0
# 199886                          Dangerous (feat. Joywave)    2          63.0
# 199887                                 Lampshades on Fire    2          63.0
# 199888                                         Primadonna    2          63.0
# 199889                                           Firebird    3          49.0
# 199890                                Scared to Be Lonely    3          49.0
# 199891                          Limelight - NGHTMRE Remix    3          49.0
# 199892                                          Carmalude    3          49.0
# 199893                           Stay (with Alessia Cara)    3          49.0
#
#         trackindex
# 199875       76258
# 199876        3871
# 199877       44050
# 199878       46400
# 199879       92718
# 199880       44532
# 199881       13981
# 199882       81402
# 199883       66069
# 199884       62807
# 199885       72856
# 199886       56422
# 199887       81435
# 199888         596
# 199889       94782
# 199890       52055
# 199891       18658
# 199892       93577
# 199893        9097

# %%
#First save the challenge playlists using the same format as trianing
#ie. sparse dok matrix
chall_mat = sp.dok_matrix((4, 110716), dtype=np.float32)
for pid, trackindex in zip(sample_challenge['pid'], sample_challenge['trackindex']):
    chall_mat[pid, trackindex] = 1.0

# %%
playlist_input, track_input, labels = get_train_instances(chall_mat, 0)

# %%
predictions = model.predict([np.array(playlist_input), np.array(track_input)])

# %%
predictions
# Out:
# array([[  1.84105467e-02],
#        [  1.93946925e-03],
#        [  9.88554180e-01],
#        [  2.85070785e-03],
#        [  1.51838904e-04],
#        [  3.03956727e-03],
#        [  3.86640383e-03],
#        [  4.51667984e-05],
#        [  1.20616639e-02],
#        [  2.82539101e-03],
#        [  4.91999381e-05],
#        [  7.64941284e-03],
#        [  1.88684076e-04],
#        [  1.38368189e-01],
#        [  4.61007096e-03],
#        [  2.47132294e-02],
#        [  1.54368463e-03],
#        [  9.71875131e-01],
#        [  2.28365549e-04]], dtype=float32)
